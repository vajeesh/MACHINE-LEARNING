# %%
# Below code is for getting figure in center alignment
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %% [markdown]
# # Basic Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from scipy import stats

# To avoid warinings
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading data
df = pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8 (1).xls',index_col=0)
print(df.shape)
df.head(3)
# Out:
# (1200, 27)
#            Age Gender EducationBackground MaritalStatus EmpDepartment  \
# EmpNumber
# E1001000    32   Male           Marketing        Single         Sales
# E1001006    47   Male           Marketing        Single         Sales
# E1001007    40   Male       Life Sciences       Married         Sales
#
#                 EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# EmpNumber
# E1001000   Sales Executive           Travel_Rarely                10
# E1001006   Sales Executive           Travel_Rarely                14
# E1001007   Sales Executive       Travel_Frequently                 5
#
#            EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# EmpNumber                                                 ...
# E1001000                   3                           4  ...
# E1001006                   4                           4  ...
# E1001007                   4                           4  ...
#
#            EmpRelationshipSatisfaction  TotalWorkExperienceInYears  \
# EmpNumber
# E1001000                             4                          10
# E1001006                             4                          20
# E1001007                             3                          20
#
#            TrainingTimesLastYear  EmpWorkLifeBalance  \
# EmpNumber
# E1001000                       2                   2
# E1001006                       2                   3
# E1001007                       2                   3
#
#            ExperienceYearsAtThisCompany ExperienceYearsInCurrentRole  \
# EmpNumber
# E1001000                             10                            7
# E1001006                              7                            7
# E1001007                             18                           13
#
#            YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# EmpNumber
# E1001000                         0                     8         No
# E1001006                         1                     7         No
# E1001007                         1                    12         No
#
#            PerformanceRating
# EmpNumber
# E1001000                   3
# E1001006                   3
# E1001007                   4
#
# [3 rows x 27 columns]

# %% [markdown]
# ### Information about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, E1001000 to E100998
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           1200 non-null   int64
#  1   Gender                        1200 non-null   object
#  2   EducationBackground           1200 non-null   object
#  3   MaritalStatus                 1200 non-null   object
#  4   EmpDepartment                 1200 non-null   object
#  5   EmpJobRole                    1200 non-null   object
#  6   BusinessTravelFrequency       1200 non-null   object
#  7   DistanceFromHome              1200 non-null   int64
#  8   EmpEducationLevel             1200 non-null   int64
#  9   EmpEnvironmentSatisfaction    1200 non-null   int64
#  10  EmpHourlyRate                 1200 non-null   int64
#  11  EmpJobInvolvement             1200 non-null   int64
#  12  EmpJobLevel                   1200 non-null   int64
#  13  EmpJobSatisfaction            1200 non-null   int64
#  14  NumCompaniesWorked            1200 non-null   int64
#  15  OverTime                      1200 non-null   object
#  16  EmpLastSalaryHikePercent      1200 non-null   int64
#  17  EmpRelationshipSatisfaction   1200 non-null   int64
#  18  TotalWorkExperienceInYears    1200 non-null   int64
#  19  TrainingTimesLastYear         1200 non-null   int64
#  20  EmpWorkLifeBalance            1200 non-null   int64
#  21  ExperienceYearsAtThisCompany  1200 non-null   int64
#  22  ExperienceYearsInCurrentRole  1200 non-null   int64
#  23  YearsSinceLastPromotion       1200 non-null   int64
#  24  YearsWithCurrManager          1200 non-null   int64
#  25  Attrition                     1200 non-null   object
#  26  PerformanceRating             1200 non-null   int64
# dtypes: int64(19), object(8)
# memory usage: 262.5+ KB

# %% [markdown]
# # Analyze Features by describing data

# %%
print(df.columns)# To find the features present in the data set
# Out:
# Index(['Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %% [markdown]
# # Statistical Info about data

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# 50%                      3.000000      66.000000           3.000000
# 75%                      4.000000      83.000000           3.000000
# max                      4.000000     100.000000           4.000000
#
#        EmpJobLevel  EmpJobSatisfaction  NumCompaniesWorked  \
# count  1200.000000         1200.000000         1200.000000
# mean      2.067500            2.732500            2.665000
# std       1.107836            1.100888            2.469384
# min       1.000000            1.000000            0.000000
# 25%       1.000000            2.000000            1.000000
# 50%       2.000000            3.000000            2.000000
# 75%       3.000000            4.000000            4.000000
# max       5.000000            4.000000            9.000000
#
#        EmpLastSalaryHikePercent  EmpRelationshipSatisfaction  \
# count               1200.000000                  1200.000000
# mean                  15.222500                     2.725000
# std                    3.625918                     1.075642
# min                   11.000000                     1.000000
# 25%                   12.000000                     2.000000
# 50%                   14.000000                     3.000000
# 75%                   18.000000                     4.000000
# max                   25.000000                     4.000000
#
#        TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# count                 1200.000000            1200.000000         1200.000000
# mean                    11.330000               2.785833            2.744167
# std                      7.797228               1.263446            0.699374
# min                      0.000000               0.000000            1.000000
# 25%                      6.000000               2.000000            2.000000
# 50%                     10.000000               3.000000            3.000000
# 75%                     15.000000               3.000000            3.000000
# max                     40.000000               6.000000            4.000000
#
#        ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# count                   1200.000000                   1200.000000
# mean                       7.077500                      4.291667
# std                        6.236899                      3.613744
# min                        0.000000                      0.000000
# 25%                        3.000000                      2.000000
# 50%                        5.000000                      3.000000
# 75%                       10.000000                      7.000000
# max                       40.000000                     18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  PerformanceRating
# count              1200.000000           1200.000000        1200.000000
# mean                  2.194167              4.105000           2.948333
# std                   3.221560              3.541576           0.518866
# min                   0.000000              0.000000           2.000000
# 25%                   0.000000              2.000000           3.000000
# 50%                   1.000000              3.000000           3.000000
# 75%                   3.000000              7.000000           3.000000
# max                  15.000000             17.000000           4.000000

# %% [markdown]
# ### Check for cardinality
# * This is all about how many distinct values are in a column.<br>

# %%
df.describe(exclude='number')
# Out:
#        Gender EducationBackground MaritalStatus EmpDepartment  \
# count    1200                1200          1200          1200
# unique      2                   6             3             6
# top      Male       Life Sciences       Married         Sales
# freq      725                 492           548           373
#
#              EmpJobRole BusinessTravelFrequency OverTime Attrition
# count              1200                    1200     1200      1200
# unique               19                       3        2         2
# top     Sales Executive           Travel_Rarely       No        No
# freq                270                     846      847      1022

# %% [markdown]
# ### Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Numerical Features

# %%
num_data = df[['Age','DistanceFromHome','EmpHourlyRate','NumCompaniesWorked','EmpLastSalaryHikePercent', 'TotalWorkExperienceInYears',
              'TrainingTimesLastYear','ExperienceYearsAtThisCompany','ExperienceYearsInCurrentRole','YearsSinceLastPromotion',
              'YearsWithCurrManager']]
num_data
# Out:
#            Age  DistanceFromHome  EmpHourlyRate  NumCompaniesWorked  \
# EmpNumber
# E1001000    32                10             55                   1
# E1001006    47                14             42                   2
# E1001007    40                 5             48                   5
# E1001009    41                10             73                   3
# E1001010    60                16             84                   8
# ...        ...               ...            ...                 ...
# E100992     27                 3             71                   1
# E100993     37                10             80                   3
# E100994     50                28             74                   1
# E100995     34                 9             46                   1
# E100998     24                 3             65                   9
#
#            EmpLastSalaryHikePercent  TotalWorkExperienceInYears  \
# EmpNumber
# E1001000                         12                          10
# E1001006                         12                          20
# E1001007                         21                          20
# E1001009                         15                          23
# E1001010                         14                          10
# ...                             ...                         ...
# E100992                          20                           6
# E100993                          17                           4
# E100994                          11                          20
# E100995                          14                           9
# E100998                          14                           4
#
#            TrainingTimesLastYear  ExperienceYearsAtThisCompany  \
# EmpNumber
# E1001000                       2                            10
# E1001006                       2                             7
# E1001007                       2                            18
# E1001009                       2                            21
# E1001010                       1                             2
# ...                          ...                           ...
# E100992                        3                             6
# E100993                        2                             1
# E100994                        3                            20
# E100995                        3                             8
# E100998                        3                             2
#
#            ExperienceYearsInCurrentRole  YearsSinceLastPromotion  \
# EmpNumber
# E1001000                              7                        0
# E1001006                              7                        1
# E1001007                             13                        1
# E1001009                              6                       12
# E1001010                              2                        2
# ...                                 ...                      ...
# E100992                               5                        0
# E100993                               0                        0
# E100994                               8                        3
# E100995                               7                        7
# E100998                               2                        2
#
#            YearsWithCurrManager
# EmpNumber
# E1001000                      8
# E1001006                      7
# E1001007                     12
# E1001009                      6
# E1001010                      2
# ...                         ...
# E100992                       4
# E100993                       0
# E100994                       8
# E100995                       7
# E100998                       0
#
# [1200 rows x 11 columns]

# %% [markdown]
# # Check for Normal Distribution
# #### Checking weather the data is normally distributed or NOT

# %%
sb.set(rc={"font.size":15,"axes.titlesize":20,"axes.labelsize":15,"xtick.labelsize":10,"ytick.labelsize":10,
            "legend.fontsize":8},style="darkgrid")
fig = plt.figure(figsize=(15,25),dpi=100)
for index,col in enumerate(num_data):
    plt.subplot(7,2,index+1)
    sb.distplot(num_data.loc[:,col].dropna(),kde=True,bins=30)
fig.tight_layout(pad=4.0)

# %%
# Defining a function for checking  skewness
from scipy.stats import skew, kurtosis
def skewedness(data):
    skewed=[]
    for col in data:
        sk=skew(data[col])
        if(sk>=1.96 or sk<=-1.96):
            skewed.append(col)
    return skewed

print(skewedness(num_data))
print('Range of skewness & kurtosis, S< |1.96|')
# Checking Kurtosis
print('skewness for YearsSinceLastPromotion:',skew(df.YearsSinceLastPromotion))
print('kurtosis for YearsSinceLastPromotion:',kurtosis(df.YearsSinceLastPromotion))
# Out:
# ['YearsSinceLastPromotion']
# Range of skewness & kurtosis, S< |1.96|
# skewness for YearsSinceLastPromotion: 1.9724620367914252
# kurtosis for YearsSinceLastPromotion: 3.5193552691799805

# %% [markdown]
# ## Transforming Skewed Data for Machine Learning
# Skewed data is common in data science: skew is the degree of distortion from a normal distribution.

# %%
# Set figure size for the notebook
plt.rcParams["figure.figsize"]=10,7
sb.distplot(df['YearsSinceLastPromotion'])
plt.show()

# %% [markdown]
# ### Square Root Transformation
# <b>Square root transformation</b> is one of the many types of standard transformations.This transformation is used for count data (data that follow a Poisson distribution) or small whole numbers. Each data point is replaced by its square root. Negative data is converted to positive by adding a constant, and then transformed.

# %%
# applying square root to the skewed column
df['YearsSinceLastPromotion'] = np.sqrt(df['YearsSinceLastPromotion'])

# %%
df['YearsSinceLastPromotion'].skew()
# Out:
# 0.7350121906940618

# %%
# Set figure size for the notebook
plt.rcParams["figure.figsize"]=10,7
sb.distplot(df['YearsSinceLastPromotion'])
plt.show()

# %%
num_data['YearsSinceLastPromotion']
# Out:
# EmpNumber
# E1001000     0
# E1001006     1
# E1001007     1
# E1001009    12
# E1001010     2
#             ..
# E100992      0
# E100993      0
# E100994      3
# E100995      7
# E100998      2
# Name: YearsSinceLastPromotion, Length: 1200, dtype: int64

# %%
# checking for skewed columns
from scipy.stats import skew, kurtosis
def skewedness(data):
    skewed=[]
    for col in data:
        sk=skew(data[col])
        if(sk>=1.96 or sk<=-1.96):
            skewed.append(col)
    return skewed

print(skewedness(num_data))
# Out:
# ['YearsSinceLastPromotion']

# %% [markdown]
# ## Data Analysis

# %%
# Set figure size for the notebook
plt.rcParams["figure.figsize"]=10,7

# set seaborn whitegrid theme
sb.set(style="darkgrid")
# Density chart
sb.kdeplot(df['Age'], fill=True,alpha=0.6)
plt.title('\nDensity chart for Age Analysis\n',fontsize=16, color='black')
plt.show()

# %% [markdown]
# The age distribution is starting from 18 to 60 where the most of the employees are lying between 30 to 40 age count.

# %% [markdown]
# ## Ordinal features

# %%
# Defing ordinal features
ord_data = df[['EmpEducationLevel','EmpEnvironmentSatisfaction','EmpJobInvolvement','EmpJobLevel','EmpJobSatisfaction',
'EmpRelationshipSatisfaction','EmpWorkLifeBalance']]
# figure size for the notebook
plt.figure(figsize=(15,25))
# Creating loop for ploting ordinal features
for index,cols in enumerate(ord_data):
    plt.subplot(7,2,index+1)
    sb.distplot(ord_data.loc[:,cols])
plt.tight_layout(pad=2)

# %% [markdown]
# ## Categorical features

# %%
# storing object type data in obj_data variable
obj_data = df.select_dtypes(include="object")
obj_data
# Out:
#            Gender EducationBackground MaritalStatus    EmpDepartment  \
# EmpNumber
# E1001000     Male           Marketing        Single            Sales
# E1001006     Male           Marketing        Single            Sales
# E1001007     Male       Life Sciences       Married            Sales
# E1001009     Male     Human Resources      Divorced  Human Resources
# E1001010     Male           Marketing        Single            Sales
# ...           ...                 ...           ...              ...
# E100992    Female             Medical      Divorced            Sales
# E100993      Male       Life Sciences        Single      Development
# E100994      Male             Medical       Married      Development
# E100995    Female             Medical        Single     Data Science
# E100998    Female       Life Sciences        Single            Sales
#
#                  EmpJobRole BusinessTravelFrequency OverTime Attrition
# EmpNumber
# E1001000    Sales Executive           Travel_Rarely       No        No
# E1001006    Sales Executive           Travel_Rarely       No        No
# E1001007    Sales Executive       Travel_Frequently      Yes        No
# E1001009            Manager           Travel_Rarely       No        No
# E1001010    Sales Executive           Travel_Rarely       No        No
# ...                     ...                     ...      ...       ...
# E100992     Sales Executive       Travel_Frequently      Yes        No
# E100993    Senior Developer           Travel_Rarely       No        No
# E100994    Senior Developer           Travel_Rarely      Yes        No
# E100995      Data Scientist           Travel_Rarely       No        No
# E100998     Sales Executive           Travel_Rarely       No       Yes
#
# [1200 rows x 8 columns]

# %%
# combining numerical, ordinal & categorial features
final_df = pd.concat([num_data,ord_data,obj_data,df['PerformanceRating']], axis=1)
final_df
# Out:
#            Age  DistanceFromHome  EmpHourlyRate  NumCompaniesWorked  \
# EmpNumber
# E1001000    32                10             55                   1
# E1001006    47                14             42                   2
# E1001007    40                 5             48                   5
# E1001009    41                10             73                   3
# E1001010    60                16             84                   8
# ...        ...               ...            ...                 ...
# E100992     27                 3             71                   1
# E100993     37                10             80                   3
# E100994     50                28             74                   1
# E100995     34                 9             46                   1
# E100998     24                 3             65                   9
#
#            EmpLastSalaryHikePercent  TotalWorkExperienceInYears  \
# EmpNumber
# E1001000                         12                          10
# E1001006                         12                          20
# E1001007                         21                          20
# E1001009                         15                          23
# E1001010                         14                          10
# ...                             ...                         ...
# E100992                          20                           6
# E100993                          17                           4
# E100994                          11                          20
# E100995                          14                           9
# E100998                          14                           4
#
#            TrainingTimesLastYear  ExperienceYearsAtThisCompany  \
# EmpNumber
# E1001000                       2                            10
# E1001006                       2                             7
# E1001007                       2                            18
# E1001009                       2                            21
# E1001010                       1                             2
# ...                          ...                           ...
# E100992                        3                             6
# E100993                        2                             1
# E100994                        3                            20
# E100995                        3                             8
# E100998                        3                             2
#
#            ExperienceYearsInCurrentRole  YearsSinceLastPromotion  ...  \
# EmpNumber                                                         ...
# E1001000                              7                        0  ...
# E1001006                              7                        1  ...
# E1001007                             13                        1  ...
# E1001009                              6                       12  ...
# E1001010                              2                        2  ...
# ...                                 ...                      ...  ...
# E100992                               5                        0  ...
# E100993                               0                        0  ...
# E100994                               8                        3  ...
# E100995                               7                        7  ...
# E100998                               2                        2  ...
#
#            EmpWorkLifeBalance  Gender  EducationBackground  MaritalStatus  \
# EmpNumber
# E1001000                    2    Male            Marketing         Single
# E1001006                    3    Male            Marketing         Single
# E1001007                    3    Male        Life Sciences        Married
# E1001009                    2    Male      Human Resources       Divorced
# E1001010                    3    Male            Marketing         Single
# ...                       ...     ...                  ...            ...
# E100992                     3  Female              Medical       Divorced
# E100993                     3    Male        Life Sciences         Single
# E100994                     3    Male              Medical        Married
# E100995                     4  Female              Medical         Single
# E100998                     3  Female        Life Sciences         Single
#
#              EmpDepartment        EmpJobRole  BusinessTravelFrequency  \
# EmpNumber
# E1001000             Sales   Sales Executive            Travel_Rarely
# E1001006             Sales   Sales Executive            Travel_Rarely
# E1001007             Sales   Sales Executive        Travel_Frequently
# E1001009   Human Resources           Manager            Travel_Rarely
# E1001010             Sales   Sales Executive            Travel_Rarely
# ...                    ...               ...                      ...
# E100992              Sales   Sales Executive        Travel_Frequently
# E100993        Development  Senior Developer            Travel_Rarely
# E100994        Development  Senior Developer            Travel_Rarely
# E100995       Data Science    Data Scientist            Travel_Rarely
# E100998              Sales   Sales Executive            Travel_Rarely
#
#            OverTime Attrition PerformanceRating
# EmpNumber
# E1001000         No        No                 3
# E1001006         No        No                 3
# E1001007        Yes        No                 4
# E1001009         No        No                 3
# E1001010         No        No                 3
# ...             ...       ...               ...
# E100992         Yes        No                 4
# E100993          No        No                 3
# E100994         Yes        No                 3
# E100995          No        No                 3
# E100998          No       Yes                 2
#
# [1200 rows x 27 columns]

# %%
# Converting Labeled data to Numerical data using label Encoder
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
final_df[['Gender', 'EducationBackground', 'MaritalStatus', 'EmpDepartment',
       'EmpJobRole', 'BusinessTravelFrequency', 'OverTime', 'Attrition']] = final_df[['Gender', 'EducationBackground', 
        'MaritalStatus', 'EmpDepartment','EmpJobRole', 'BusinessTravelFrequency', 'OverTime', 'Attrition']].apply(label.fit_transform)

# %% [markdown]
# # Correlation Heatmap
# * Correlation is a statistical measure that expresses the extent to which two variables are linearly related (means they change together at a constant rate)
# <br>
# * By plotting a correlation matrix, we have a very nice overview of how the features are related to one another. For a Pandas data frame, we can conveniently use the call .corr which by default provides the Pearson Correlation values of the columns pairwise in that data frame. The correlation works bet for numerical data where we are going to use all the numerical features present in the data.

# %%
plt.figure(figsize=(30,25))
plt.title('Heatmap')
sb.despine()
sb.heatmap(final_df.corr(),linewidths=0.6, annot=True,square=True,fmt='.2f',cmap='Spectral')
plt.show()

# %% [markdown]
# These three variables are positively correlated with performance rating( Target variable)<br>
# 1. EmpEnvironmentSatisfaction<br>
# * EmpLastSalaryHikePercent<br>
# * EmpWorkLifeBalance

# %%
# defing Independent variables as X
X = final_df.iloc[:,:-1]
# Defing Target variable or dependent variable
y = final_df.iloc[:,-1]
X
# Out:
#            Age  DistanceFromHome  EmpHourlyRate  NumCompaniesWorked  \
# EmpNumber
# E1001000    32                10             55                   1
# E1001006    47                14             42                   2
# E1001007    40                 5             48                   5
# E1001009    41                10             73                   3
# E1001010    60                16             84                   8
# ...        ...               ...            ...                 ...
# E100992     27                 3             71                   1
# E100993     37                10             80                   3
# E100994     50                28             74                   1
# E100995     34                 9             46                   1
# E100998     24                 3             65                   9
#
#            EmpLastSalaryHikePercent  TotalWorkExperienceInYears  \
# EmpNumber
# E1001000                         12                          10
# E1001006                         12                          20
# E1001007                         21                          20
# E1001009                         15                          23
# E1001010                         14                          10
# ...                             ...                         ...
# E100992                          20                           6
# E100993                          17                           4
# E100994                          11                          20
# E100995                          14                           9
# E100998                          14                           4
#
#            TrainingTimesLastYear  ExperienceYearsAtThisCompany  \
# EmpNumber
# E1001000                       2                            10
# E1001006                       2                             7
# E1001007                       2                            18
# E1001009                       2                            21
# E1001010                       1                             2
# ...                          ...                           ...
# E100992                        3                             6
# E100993                        2                             1
# E100994                        3                            20
# E100995                        3                             8
# E100998                        3                             2
#
#            ExperienceYearsInCurrentRole  YearsSinceLastPromotion  ...  \
# EmpNumber                                                         ...
# E1001000                              7                        0  ...
# E1001006                              7                        1  ...
# E1001007                             13                        1  ...
# E1001009                              6                       12  ...
# E1001010                              2                        2  ...
# ...                                 ...                      ...  ...
# E100992                               5                        0  ...
# E100993                               0                        0  ...
# E100994                               8                        3  ...
# E100995                               7                        7  ...
# E100998                               2                        2  ...
#
#            EmpRelationshipSatisfaction  EmpWorkLifeBalance  Gender  \
# EmpNumber
# E1001000                             4                   2       1
# E1001006                             4                   3       1
# E1001007                             3                   3       1
# E1001009                             2                   2       1
# E1001010                             4                   3       1
# ...                                ...                 ...     ...
# E100992                              2                   3       0
# E100993                              1                   3       1
# E100994                              3                   3       1
# E100995                              2                   4       0
# E100998                              1                   3       0
#
#            EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# EmpNumber
# E1001000                     2              2              5          13
# E1001006                     2              2              5          13
# E1001007                     1              1              5          13
# E1001009                     0              0              3           8
# E1001010                     2              2              5          13
# ...                        ...            ...            ...         ...
# E100992                      3              0              5          13
# E100993                      1              2              1          15
# E100994                      3              1              1          15
# E100995                      3              2              0           1
# E100998                      1              2              5          13
#
#            BusinessTravelFrequency  OverTime  Attrition
# EmpNumber
# E1001000                         2         0          0
# E1001006                         2         0          0
# E1001007                         1         1          0
# E1001009                         2         0          0
# E1001010                         2         0          0
# ...                            ...       ...        ...
# E100992                          1         1          0
# E100993                          2         0          0
# E100994                          2         1          0
# E100995                          2         0          0
# E100998                          2         0          1
#
# [1200 rows x 26 columns]

# %% [markdown]
# ## Handling Imbalanced data
# #### Converting Imbalance data into balanced data
#
# * Balancing data with SMOTE Technique gives more number of NaN values
# * so, we use RandomOverSampler Technique to balance the data

# %%
# Imports
from imblearn.over_sampling import RandomOverSampler,SMOTENC,SMOTE
# Intilizing the model
oversampling = RandomOverSampler()
X_smote, y_smote = oversampling.fit_sample(X,y)
X_smote = pd.DataFrame(X_smote)
X_smote.columns = ['Age', 'DistanceFromHome', 'EmpHourlyRate', 'NumCompaniesWorked',
       'EmpLastSalaryHikePercent', 'TotalWorkExperienceInYears',
       'TrainingTimesLastYear', 'ExperienceYearsAtThisCompany',
       'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager', 'EmpEducationLevel',
       'EmpEnvironmentSatisfaction', 'EmpJobInvolvement', 'EmpJobLevel',
       'EmpJobSatisfaction', 'EmpRelationshipSatisfaction',
       'EmpWorkLifeBalance', 'Gender', 'EducationBackground', 'MaritalStatus',
       'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency', 'OverTime',
       'Attrition']
X_smote
# Out:
#       Age  DistanceFromHome  EmpHourlyRate  NumCompaniesWorked  \
# 0      32                10             55                   1
# 1      47                14             42                   2
# 2      40                 5             48                   5
# 3      41                10             73                   3
# 4      60                16             84                   8
# ...   ...               ...            ...                 ...
# 2617   30                 4             40                   9
# 2618   31                 7             48                   3
# 2619   37                19             73                   4
# 2620   45                28             97                   4
# 2621   41                 9             94                   1
#
#       EmpLastSalaryHikePercent  TotalWorkExperienceInYears  \
# 0                           12                          10
# 1                           12                          20
# 2                           21                          20
# 3                           15                          23
# 4                           14                          10
# ...                        ...                         ...
# 2617                        23                           3
# 2618                        22                          10
# 2619                        21                           8
# 2620                        20                           8
# 2621                        20                           5
#
#       TrainingTimesLastYear  ExperienceYearsAtThisCompany  \
# 0                         2                            10
# 1                         2                             7
# 2                         2                            18
# 3                         2                            21
# 4                         1                             2
# ...                     ...                           ...
# 2617                      4                             1
# 2618                      3                             7
# 2619                      1                             1
# 2620                      3                             5
# 2621                      2                             5
#
#       ExperienceYearsInCurrentRole  YearsSinceLastPromotion  ...  \
# 0                                7                        0  ...
# 1                                7                        1  ...
# 2                               13                        1  ...
# 3                                6                       12  ...
# 4                                2                        2  ...
# ...                            ...                      ...  ...
# 2617                             0                        0  ...
# 2618                             7                        1  ...
# 2619                             0                        0  ...
# 2620                             4                        0  ...
# 2621                             3                        0  ...
#
#       EmpRelationshipSatisfaction  EmpWorkLifeBalance  Gender  \
# 0                               4                   2       1
# 1                               4                   3       1
# 2                               3                   3       1
# 3                               2                   2       1
# 4                               4                   3       1
# ...                           ...                 ...     ...
# 2617                            3                   3       1
# 2618                            4                   2       1
# 2619                            1                   3       1
# 2620                            4                   3       1
# 2621                            2                   3       1
#
#       EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0                       2              2              5          13
# 1                       2              2              5          13
# 2                       1              1              5          13
# 3                       0              0              3           8
# 4                       2              2              5          13
# ...                   ...            ...            ...         ...
# 2617                    5              2              1           3
# 2618                    1              0              1           3
# 2619                    1              1              1           3
# 2620                    5              1              4          12
# 2621                    1              0              4           7
#
#       BusinessTravelFrequency  OverTime  Attrition
# 0                           2         0          0
# 1                           2         0          0
# 2                           1         1          0
# 3                           2         0          0
# 4                           2         0          0
# ...                       ...       ...        ...
# 2617                        1         1          1
# 2618                        2         0          0
# 2619                        2         0          0
# 2620                        2         0          0
# 2621                        2         0          0
#
# [2622 rows x 26 columns]

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

bestfeatures = SelectKBest(score_func=chi2,k=15)
fit = bestfeatures.fit(X_smote,y_smote)

dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_smote.columns)

featurescores = pd.concat([dfcolumns,dfscores],axis=1)
featurescores.columns = ['feature_names','Scores']

print(featurescores.nlargest(5,'Scores'))
# Out:
#                    feature_names       Scores
# 4       EmpLastSalaryHikePercent  1262.636271
# 9        YearsSinceLastPromotion   750.224424
# 12    EmpEnvironmentSatisfaction   457.029310
# 7   ExperienceYearsAtThisCompany   433.751149
# 8   ExperienceYearsInCurrentRole   410.916826

# %% [markdown]
# From Feature Selection Technique. We get <b> Top 5 </b> features which effect the <b> Target variable</b> Performance Rating
# * EmpLastSalaryHikePercent
# * YearsSinceLastPromotion
# * ExperienceYearsAtThisCompany
# * EmpEnvironmentSatisfaction
# * ExperienceYearsInCurrentRole
